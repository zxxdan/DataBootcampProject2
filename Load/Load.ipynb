# %%
import pandas as pd
from sqlalchemy import create_engine
from config import user, password
import os
from create_db import create_db

# %%
create_db()
# Out:
# 'Success'

# %%
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@localhost:5432/collisions_db")
UK_Final_file = os.path.join("..","Staging","UK_Final.csv")
Canada_Final_file = os.path.join("..","Staging","Canada_Final.csv")

# %%
uk_final_df = pd.read_csv(UK_Final_file, low_memory = False)
canada_final_df = pd.read_csv(Canada_Final_file, low_memory = False)

# %%
connection = engine.connect()

# %%
uk_final_df.to_sql("Collision_Data_UK",connection, if_exists="replace")

# %%
canada_final_df.to_sql("Collision_Data_Canada",connection, if_exists="replace")

# %%
test_uk = pd.read_sql_table("Collision_Data_UK",connection)
test_uk.head()
# Out:
#    index  Collision_Year  Collision_Month       Casualty_Position  \
# 0      0            2009                1            Motorcyclist
# 1      1            2009                1            Motorcyclist
# 2      2            2009                5  Motor Vehicle Occupant
# 3      3            2009                5  Motor Vehicle Occupant
# 4      4            2009                5  Motor Vehicle Occupant
#
#   Casualty_Severity Casualty_Gender  Casualty_Age  Number_of_Vehicles  \
# 0         Non-Fatal            Male            77                   2
# 1         Non-Fatal            Male            77                   2
# 2         Non-Fatal            Male            40                   2
# 3         Non-Fatal            Male            40                   2
# 4         Non-Fatal            Male            38                   2
#
#         Vehicle_Type  Vehicle_Year Driver_Gender  Driver_Age Accident_Index
# ...

# %%
test_can = pd.read_sql_table("Collision_Data_Canada",connection)
test_can.head()
# Out:
#    index  Collision_Year  Collision_Month Collision_Severity  \
# 0      0            2009                1          Non-Fatal
# 1      1            2009                1          Non-Fatal
# 2      2            2009                1          Non-Fatal
# 3      3            2009                1          Non-Fatal
# 4      4            2009                1          Non-Fatal
#
#   Number_of_Vehicles       Vehicle_Type Person_Gender         Person_Position  \
# 0                 01  Passenger Vehicle          Male  Motor Vehicle Occupant
# 1                 01  Passenger Vehicle        Female  Motor Vehicle Occupant
# 2                 01  Passenger Vehicle        Female  Motor Vehicle Occupant
# 3                 02  Passenger Vehicle        Female  Motor Vehicle Occupant
# 4                 02  Passenger Vehicle          Male  Motor Vehicle Occupant
#
#    Person_Age Vehicle_Year
# 0          75  Undisclosed
# 1          21  Undisclosed
# 2          34  Undisclosed
# ...
